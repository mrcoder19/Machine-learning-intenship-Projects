# %%
# import Libriries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loadign dataset where we can implement different function or method
df=pd.read_csv('C:\\Users\\hp\\Downloads\\Compressed\\archive_12\\Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# finding shape where where you can see Dataset columns and Rows
df.shape
# Out:
# (2938, 22)

# %%
# seeing information about the whole dataset columns[datatype of columns , checking is it null, and size]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# finding missing value
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Average of missing value
df.isnull().sum()/df.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# Find duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
# Finding grabage value

for i in df.select_dtypes(include='object'):
    print(df[i].value_counts())
    print('***'*10)
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64
# ******************************
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
# ******************************

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %%
#describe the dataset mean ( check the mean, stander dication, meamn , 25% , 50%, 75% percentile)
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.describe(include='object')
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
# Ploting Histograme of Each column 
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
# ploting boxplot for show outlier
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df, x=i)
    plt.show()

# %%
# printing the columns name of dataset
print(df.select_dtypes(include="number").columns)
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# ploting scatterplot to find relationg columns[Life Expetancy] with all other column
for i in ['Year', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
    sns.scatterplot(data=df, x=i,y='Life expectancy ',hue='Life expectancy ')
    plt.show()

# %% [markdown]
# Duplicated value tearmenated

# %%
# drop or remove the duplicate value
df=df.drop_duplicates()

# %%
# checking the duplicate value
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Null value tharmenated

# %%
# checking null value
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# print the datatype 
print(df.dtypes)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
# Handling missing value or imputing missing value 
from sklearn.impute import SimpleImputer

mean_impute=SimpleImputer(strategy='mean')
df['Life expectancy ']=mean_impute.fit_transform(df[['Life expectancy ']])
df['Adult Mortality']=mean_impute.fit_transform(df[['Adult Mortality']])
median_impute=SimpleImputer(strategy='median')
df['Alcohol']=median_impute.fit_transform(df[['Alcohol']])
df['Polio']=median_impute.fit_transform(df[['Polio']])
median_impute=SimpleImputer(strategy='most_frequent')
df['Total expenditure']=median_impute.fit_transform(df[['Total expenditure']])
df['Hepatitis B']=median_impute.fit_transform(df[['Hepatitis B']])
df['GDP']=median_impute.fit_transform(df[['GDP']])
df['Income composition of resources']=median_impute.fit_transform(df[['Income composition of resources']])
df['Schooling']=median_impute.fit_transform(df[['Schooling']])
df['Population']=median_impute.fit_transform(df[['Population']])

# %%
df.isnull().sum()
# Out:
# Country                             0
# Year                                0
# Status                              0
# Life expectancy                     0
# Adult Mortality                     0
# infant deaths                       0
# Alcohol                             0
# percentage expenditure              0
# Hepatitis B                         0
# Measles                             0
#  BMI                               34
# under-five deaths                   0
# Polio                               0
# Total expenditure                   0
# Diphtheria                         19
#  HIV/AIDS                           0
# GDP                                 0
# Population                          0
#  thinness  1-19 years              34
#  thinness 5-9 years                34
# Income composition of resources     0
# Schooling                           0
# dtype: int64

# %%
# Drop column where is null value
df.dropna(axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# Encoding Data

# %%
# Encoding the country column
pd.get_dummies(data=df, columns=['Country','Status'],drop_first=True)
# Out:
#       Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015              65.0            263.0             62     0.01
# 1     2014              59.9            271.0             64     0.01
# 2     2013              59.9            268.0             66     0.01
# 3     2012              59.5            272.0             69     0.01
# 4     2011              59.2            275.0             71     0.01
# ...    ...               ...              ...            ...      ...
# 2933  2004              44.3            723.0             27     4.36
# 2934  2003              44.5            715.0             26     4.06
# 2935  2002              44.8             73.0             25     4.43
# 2936  2001              45.3            686.0             25     1.72
# 2937  2000              46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles   under-five deaths   \
# ...
